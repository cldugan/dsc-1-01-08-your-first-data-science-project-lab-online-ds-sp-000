# %% [markdown]
# ## Introduction
#
# In this lab, you'll get to do your first real data science project! You'll use Jupyter Notebook to import pre-written libraries, you'll import data into your notebook from a Comma Seperated Values file (a .csv file) and you'll even get to create some plots!
#
# Don't worry if it feels like a lot or you get confused on this lab. Our goal here is just to give you a taste of what you'll be able to do as a data scientist, and after this lab, we'll go back and re-introduce all of the concepts that we skimmed over this time through, so by the end of the section you should have a much stronger understanding of this - even if you have no previous experience of programming.
#
# Don't worry about running tests for this lab. Just take your time to explore the data and the code.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Code along (following detailed instructions) to import a csv file and then plot the data

# %% [markdown]
# ## Jupyter Notebook and Running Cells
#
# **Welcome to programming!**
# Juptyer Notebooks (historically called IPythonNotebooks) will be our primary tool when conducting data science. The first thing to know with this is that each cell block [of code] can be run be pressing **shift+enter**. Try running the below code block:

# %%
print('This is code being run.')
# Out:
# This is code being run.

# %% [markdown]
# ## Importing Packages
# The next thing we're going to do is load in some python packages that will be part of our toolbox for manipulating and analyzing data. The standard python package for working with data tables is called **pandas**. Below, we import this under the **alias** pd, which is the industry standard. This will give us a shorthand way to access special functions and methods within the package without having to type the longer name pandas.
#
# * Again, press **shift+enter** to run the code below

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Jupyter Notebook Cell Types
#
# You might have started to notice that the code blocks have little notes that say **In [ ]:** before you run them, and then are filled with a number after you run them. This is important, as it tells you what order cell blocks were run. (Which can sometimes affect how a program runs.)
#
# You may also notice that other cell blocks, such as this one, do not have the **In [ ]:** label as with the code blocks. This is because this cell block is formatted as **Markdown** rather then code. You can see (and change) what type of cell is by clicking the dropdown menu at the top:
# <img src="Jupyter_Notebook_Cell_Type_Dropdown.png" width=600>

# %% [markdown]
# # Command Versus Edit Mode
#
# You should also start to notice that when you are in a cell writing code (or notes), the cell is highlighted in **green** meaning you are in **edit mode**.
#
# Alternatively, if you **press esc**, the cursor will be in **blue** inidicating that you are in **command mode**.
#
# ### Edit Mode
# Edit mode is the standard mode for editing cells, whether its writing code or notes.
# To enter edit mode from command mode simply hit enter, or double click on a cell.
#
# ### Command Mode
# In command mode, you can delete cells, add cells, copy cells, paste cells, change cell types, and more. You can also do these tasks in a more cumbersome (and time consuming) manner by using the various headers in the menu bar at top.
# <img src="Jupyter_Menu.png" width=600>
# You can also see a full list of shortcuts available in command and edit mode under the help menu.
#
# <img src="Jupyter_Help_Menu.png" width=600>

# %% [markdown]
# # Running Bash Commands
#
# We can also run bash commands just as we did before from the terminal directly within iPython notebooks!
#  (Note: bash commands cannot be mixed with python and must be in their own cell block.)
#
# Try it out!

# %%
pwd
# Out:
# '/Users/dugan/school/dsc-1-01-08-your-first-data-science-project-lab-online-ds-sp-000'

# %%
ls
# Out:
# CONTRIBUTING.md
# Jupyter_Help_Menu.png
# Jupyter_Menu.png
# Jupyter_Notebook_Cell_Type_Dropdown.png
# LICENSE.md
# README.md
# docstring.png
# docstring_preview.png
# index.ipynb
# index_files/
# lego_sets.csv*
# pd_methods.png
# pd_read_methods.png
# python_built_in_functions.png
# string-slicing.png

# %% [markdown]
# ## Loading a DataFrame
# The primary datatype within the pandas package is called a dataframe and is similar to a spreadsheet in excel. Here's a brief example of loading a csv file from your hard drive:

# %%
df = pd.read_csv('lego_sets.csv') #Loads the dataframe in
print(len(df)) #Prints the length of the dataframe
df.head() #Uses a built in method common to all Pandas Dataframes
# Out:
# 12261
#    ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0  6-12       29.99          2.0        277.0               4.0
# 1  6-12       19.99          2.0        168.0               4.0
# 2  6-12       12.99         11.0         74.0               4.3
# 3   12+       99.99         23.0       1032.0               3.6
# 4   12+       79.99         14.0        744.0               3.2
#
#                                            prod_desc  prod_id  \
# 0  Catapult into action and take back the eggs fr...  75823.0
# 1  Launch a flying attack and rescue the eggs fro...  75822.0
# 2  Chase the piggy with lightning-fast Chuck and ...  75821.0
# 3  Explore the architecture of the United States ...  21030.0
# 4  Recreate the Solomon R. Guggenheim Museum® wit...  21035.0
#
#                                       prod_long_desc review_difficulty  \
# 0  Use the staircase catapult to launch Red into ...           Average
# 1  Pilot Pig has taken off from Bird Island with ...              Easy
# 2  Pitch speedy bird Chuck against the Piggy Car....              Easy
# 3  Discover the architectural secrets of the icon...           Average
# 4  Discover the architectural secrets of Frank Ll...       Challenging
#
#                          set_name  star_rating    theme_name  val_star_rating  \
# 0           Bird Island Egg Heist          4.5  Angry Birds™              4.0
# 1              Piggy Plane Attack          5.0  Angry Birds™              4.0
# 2                Piggy Car Escape          4.3  Angry Birds™              4.1
# 3  United States Capitol Building          4.6  Architecture              4.3
# 4   Solomon R. Guggenheim Museum®          4.6  Architecture              4.1
#
#   country
# 0      US
# 1      US
# 2      US
# 3      US
# 4      US

# %% [markdown]
# # Python Comments
#
# Note the green text following the **#**.
# Anything following a **#** in python is a comment and will not actually execute.
# This is a useful feature for annotating your code with notes for yourself and other later so that your code is easy to read.

# %% [markdown]
# # Accessing Methods from Packages and Objects
#
# A little more theory and context:
#
# When we loaded in packages on our first cell block (import pandas as pd), we loaded code into memory. That code included functions, variables and other objects. Collectively, all of these items is loaded under the package name or alias.
#
# We demonstrated this when we used the **pd.read_csv()** method above.
#
# This also demonstrates the **dot notation** in python, which is how we access built in methods or attriubtes of a given object. Similar to what we saw with bash in the command line, we can also use **tab completion** to preview methods available in packages or other objects.
#
# ### Try this out yourself
#
# * In the cell below, navigate your cursor to the right of **pd.**
# * Press tab to see a list of available methods/attributes
#
# <img src="pd_methods.png" width=600>

# %%
pd.re

# %% [markdown]
# You can also start typing to subset the list of available commands:
# <img src="pd_read_methods.png" width=600>

# %% [markdown]
# # Pulling up Docstrings
#
# Even better, you can even see how a method works by pulling up its **docstring**!
# You can do this by writing **?** after the method and running the cell.
#
# <img src="docstring.png" width=500>
#
#
# Try it out!

# %%
pd.read_csv?

# %% [markdown]
# Alternatively, you can pull up a preview of the docstring by pressing **shift+tab within the parentheses of a method**
# <img src="docstring_preview.png" width=500>

# %%
pd.read_csv() #Move your cursor inside the parentheses and press shift+tab

# %% [markdown]
# # Variables
#
# The other thing that happened in our block of code above was that we defined a **variable**.
#
# This happened in the first line of code:
# ```df = pd.read_csv('causes_of_death_cleaned.csv')```
#
# As we saw, we used the built in *read_csv* method from the *pandas* package which we imported under the *alias* *pd*.
#
# The output of this method was then assigned to the variable *df*. This is the standard syntax for declaring any variable. You do not have to specify variable types, as in many other programming languages. Simply:
#
# `variable_name = what_to_stor_in_the_variable`

# %% [markdown]
# # Built in Python Functions
#
# We also used two built in python functions:
#     * len() #Returns the lenght of an object
#     * print() #Prints stuff!
# In general, **python has reserved keywords** for built in functions like this.
# **Be sure to not name your variables any of these!**
#
# <img src="python_built_in_functions.png" width=600>

# %% [markdown]
# You can also check what type of object something is using the built in **type()** method. This can be useful when determining how to work with an object that you are unfamiliar with.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Common DataFrame Methods
# As you can see, our variable **df** is a DataFrame object (which is part of the Pandas core package). Here's some other common methods you will want to become familiar with when working with Pandas dataframes:
# * df.head()
#     * Preview the first 5 rows of a dataframe. Pass a number for more/less rows
# * df.tail(10)
#     * Preview last 10 rows (default 5 if no number given)
# * df.info()
#     * Returns column names and details about each column
# * df.columns
#     * Return column names. Note that there is no parentheses for this. This is becuase this is an attribute as opposed to a method

# %%
#df.info()#Practice using some of these methods
#df.columns
df.head(3)
# Out:
#    ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0  6-12       29.99          2.0        277.0               4.0
# 1  6-12       19.99          2.0        168.0               4.0
# 2  6-12       12.99         11.0         74.0               4.3
#
#                                            prod_desc  prod_id  \
# 0  Catapult into action and take back the eggs fr...  75823.0
# 1  Launch a flying attack and rescue the eggs fro...  75822.0
# 2  Chase the piggy with lightning-fast Chuck and ...  75821.0
#
#                                       prod_long_desc review_difficulty  \
# 0  Use the staircase catapult to launch Red into ...           Average
# 1  Pilot Pig has taken off from Bird Island with ...              Easy
# 2  Pitch speedy bird Chuck against the Piggy Car....              Easy
#
#                 set_name  star_rating    theme_name  val_star_rating country
# 0  Bird Island Egg Heist          4.5  Angry Birds™              4.0      US
# 1     Piggy Plane Attack          5.0  Angry Birds™              4.0      US
# 2       Piggy Car Escape          4.3  Angry Birds™              4.1      US

# %%
#Use tab completion to investigate at least 3 other methods under the df object. 
#Pull up their docstrings and investigate what they do.
#df.align?
#df.cumprod?
#df.boxplot()
#df.squeeze?
#df.infer_objects?
df.filter?
df.eval?
df.get?

# %% [markdown]
# # Pandas Series
#
# While the entire spreadsheet is called a **dataframe**, each individual column is known as a **series**. You can access a specific column of a pandas dataframe one of two ways:
#
# `df['col_name']`
#
# or
#
# ```df.col_name```
#
# First note that in `df['col_name']` we need 'quotations' around the column name. The quotations denote the column name is a **string**, python's built in variable type for storing text. This can alternatively be replaced with double quotes `df["col_name"]`. In general, anything in quotations is a string in python code. Occassionally, with very ill formatted column names with quotations in the names themselves, you may even need to wrap a name in triple quotes `df["""col_name"""]` . This will rarely happen in this particular context, but is also the general pattern for dealing with messy strings.
#
# Note that the second method, `df.col_name`, will only work if there are no spaces within the name of the column. Similarly to tab completion with the command line, this is a primary reason why programers use dashes (-) and underscores (_) in lieu of whitespace in their variable and file names. Also note that no quotations are used when using this format. (The column names have been stored as attributes to the DataFrame object!)

# %%
#Previewing Data

# %%
df.head(2) #preview your spreadsheet again; 2 keeps it a nice small preview
# Out:
#    ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0  6-12       29.99          2.0        277.0               4.0
# 1  6-12       19.99          2.0        168.0               4.0
#
#                                            prod_desc  prod_id  \
# 0  Catapult into action and take back the eggs fr...  75823.0
# 1  Launch a flying attack and rescue the eggs fro...  75822.0
#
#                                       prod_long_desc review_difficulty  \
# 0  Use the staircase catapult to launch Red into ...           Average
# 1  Pilot Pig has taken off from Bird Island with ...              Easy
#
#                 set_name  star_rating    theme_name  val_star_rating country
# 0  Bird Island Egg Heist          4.5  Angry Birds™              4.0      US
# 1     Piggy Plane Attack          5.0  Angry Birds™              4.0      US

# %%
df.ages.head()
# Out:
# 0    6-12
# 1    6-12
# 2    6-12
# 3     12+
# 4     12+
# Name: ages, dtype: object

# %%
df.ages[:5] #Here we introduce another new syntax the list slice [:5] this limits us to the first 5 items
# Out:
# 0    6-12
# 1    6-12
# 2    6-12
# 3     12+
# 4     12+
# Name: ages, dtype: object

# %% [markdown]
# # List and Series Slices
# Above, we introduced an entirely new programming pattern called a slice.
# The syntax for a slice is `[start:end]`.
#
# You can also pass an additional third parameter `[start:end:count_by]` which will allow you to:
# count every other: `[start:end:2]`
# count backwards: `start:end:-1]`
# or potentially much more cryptic patterns, depending on what you pass.
#
# While we could have also used `df.State.head()`, slicing works for many more datatypes. This includes the previously mentioned *strings* as well as **lists** and other iterable objects. **Series**, the columns of the pandas DataFrame are similar to python's built in *lists*, but also have additional *methods* built in to them that we will continue to investigate.

# %%
df.piece_count
# Out:
# 0         277.0
# 1         168.0
# 2          74.0
# 3        1032.0
# 4         744.0
# 5         597.0
# 6         598.0
# 7         780.0
# 8         468.0
# 9         444.0
# 10        386.0
# 11        321.0
# 12        361.0
# 13        847.0
# 14        708.0
# 15        234.0
# 16        160.0
# 17        149.0
# 18        141.0
# 19        101.0
# 20        105.0
# 21        113.0
# 22        136.0
# 23         91.0
# 24        140.0
# 25        143.0
# 26        122.0
# 27        130.0
# 28        119.0
# 29        135.0
#           ...
# 12231     267.0
# 12232     293.0
# 12233     305.0
# 12234     254.0
# 12235     198.0
# 12236     204.0
# 12237     201.0
# 12238     141.0
# 12239     124.0
# 12240       8.0
# 12241     643.0
# 12242    4867.0
# 12243    2295.0
# 12244    1403.0
# 12245     830.0
# 12246    1202.0
# 12247     914.0
# 12248     944.0
# 12249     876.0
# 12250     747.0
# 12251     521.0
# 12252     544.0
# 12253     494.0
# 12254     312.0
# 12255     341.0
# 12256     341.0
# 12257     217.0
# 12258     233.0
# 12259      48.0
# 12260     109.0
# Name: piece_count, Length: 12261, dtype: float64

# %% [markdown]
# # Common Series Methods
# Some very useful series methods include:
# * df.col_name.value_counts()
# * df.col_name.astype()
# * series.mean()     #Changing notation here: series refers to df.col_name (which is a series)!
# * series.median()
# * series.min()
# * series.max()
# * series.std()
# * series.unique()
# * series.nunique()
# * series.sample()
# * series.sort_values()
#
# There are also many more but this is a very good starting point.
# Start pulling up some docstrings and getting acquainted with reading them yourself before we go through a few of these methods together.

# %%
df.set_name.unique()

#Read the docstring and tinker! See how it works.
# Out:
# array(['Bird Island Egg Heist', 'Piggy Plane Attack', 'Piggy Car Escape',
#        'United States Capitol Building', 'Solomon R. Guggenheim Museum®',
#        'Shanghai', 'New York City', 'Buckingham Palace', 'London',
#        'Chicago', 'Arc de Triomphe', 'The Eiffel Tower', 'Sydney',
#        'BOOST Creative Toolbox', 'Go Brick Me', 'Owen & Blue',
#        'Mr. Incredible & Frozone', 'Chewbacca™', 'Han Solo™',
#        'Iron Man MK50', 'Thanos', 'Star-Lord', 'Gamora', 'Finn',
#        "Valentine's Bee", 'Wonder Woman™', 'The Flash™', 'Kylo Ren™',
#        'Rey', 'Aquaman™', 'Cyborg™', 'Marty McFly & Doc Brown',
#        'Tactical Batman™ & Superman™', 'Easter Bunny', 'Lloyd',
#        'Master Wu', 'Captain Armando Salazar', 'Captain Phasma™',
#        'Batman™', 'Iron Man', 'Captain Jack Sparrow', 'The Hulk', 'Belle',
#        'Beast', 'The Joker™', 'Black Widow', 'Robin™', 'Batgirl™',
#        'Mountain River Heist', 'Cargo Train',
#        'High-speed Passenger Train', 'Jungle Air Drop Helicopter',
#        'Coast Guard Head Quarters', 'Jungle Exploration Site',
#        'Police Station', 'Mining Experts Site', 'Fire Station',
#        'Mountain Police Headquarters', 'Cargo Terminal',
#        'Bulldozer Break-in', 'Jungle Mobile Lab', 'Mountain Arrest',
#        'Heavy-duty Rescue Helicopter', 'Mobile Command Center',
#        'Bus Station', 'Mining Heavy Driller',
#        'People pack – Fun at the beach', 'High-speed Chase',
#        '4 x 4 Response Unit', 'Dirt Road Pursuit',
#        'Jungle Halftrack Mission', 'Fire Response Unit',
#        'Pickup & Caravan', 'Heavy Cargo Transport', 'Fire Ladder Truck',
#        'Monster Truck', 'Pizza Van', 'Flexible and Straight Tracks',
#        'ATV Race Team', 'Ambulance Helicopter', 'Forest Tractor',
#        'Tow Truck Trouble', 'Wild River Escape', 'Mining Power Splitter',
#        'Mountain Police Chase', 'Sea Rescue Plane',
#        'Jungle Cargo Helicopter', 'Switching Tracks',
#        'Straight & Crossroad Plates', 'T-Junction & Curved Road Plates',
#        'Airshow Jet', 'Jungle Starter Set', 'Road Repair Truck',
#        'Coast Guard Starter Set', 'Mountain Fugitives', 'Mining Team',
#        'Speed Record Car', 'Off-Road Chase', 'Jungle Buggy',
#        'Fun in the park - City People Pack',
#        'Volcano Heavy-lift Helicopter', 'Volcano Exploration Base',
#        'Fire Boat', 'Auto Transport Heist', 'Police Patrol Boat',
#        'Volcano Supply Helicopter', 'Volcano Crawler', 'Ferry',
#        'Sailboat Rescue', 'LEGO® City Advent Calendar',
#        'Airport Cargo Plane', 'Volcano Exploration Truck',
#        'Van & Caravan', 'Money Transporter', 'Police Starter Set',
#        'Stunt Truck', 'Buggy', 'Volcano Starter Set',
#        'Airport Starter Set', 'Fire Starter Set', 'ATV Arrest',
#        'LEGO® Large Creative Brick Box',
#        'LEGO® Medium Creative Brick Box', 'Creative Suitcase',
#        'LEGO® Creative Supplement', 'LEGO® Creative Bricks',
#        'Gray Baseplate', 'Blue Baseplate', 'Green Baseplate',
#        'Blue Creativity Box', 'Green Creativity Box',
#        'Red Creativity Box', 'Orange Creativity Box', 'Brick Separator',
#        'LEGO® Creative Supplement Bright', 'Sand Baseplate',
#        'Modular Family Villa', 'Turbo Track Racer', 'Modular Skate House',
#        'Sunshine Surfer Van', 'Modular Winter Vacation',
#        'Space Shuttle Explorer', 'Modular Modern Home',
#        'Modular Poolside Holiday', 'Robo Explorer', 'Rocket Rally Car',
#        'Daredevil Stunt Plane', 'Outback Adventures', 'Mighty Dinosaurs',
#        'Mythical Creatures', 'Green Cruiser', 'Air Blazer',
#        'Drone Explorer', 'Extreme Engines', 'Fast Car',
#        'Sunset Street Bike', 'Lighthouse Point', 'Island Adventures',
#        'Beach Hut', 'Beachside Vacation', 'Twin Spin Helicopter',
#        'Propeller Plane', 'Airshow Aces', 'Chopper Transporter',
#        'Cargo Heli', 'Taj Mahal', 'Downtown Diner',
#        'Winter Village Station', 'Assembly Square', 'Big Ben',
#        'Tower Bridge', 'Carousel', 'Ferris Wheel', 'Brick Bank',
#        'Parisian Restaurant', 'Detective’s Office', 'London Bus',
#        'Volkswagen T1 Camper Van', 'Volkswagen Beetle', 'MINI Cooper',
#        'Winter Holiday Train', 'The Joker™ Manor',
#        'Flying Fox: Batmobile Airlift Attack',
#        'LEGO® DIMENSIONS™ PLAYSTATION® 4 Starter Pack',
#        'The Bat-Space Shuttle', 'Knightcrawler Tunnel Attack',
#        'Harley Quinn™ Cannonball Attack', 'Lex Luthor™ Mech Takedown',
#        'Speed Force Freeze Pursuit',
#        'The Justice League™ Anniversary Party',
#        'Egghead™ Mech Food Fight', 'The Joker™ Batcave Attack',
#        'The Bat-Dune Buggy', 'Battle of Atlantis',
#        'Superman™ & Krypto™ Team-Up', 'Super Hero High School',
#        'Batgirl™ Batjet Chase', 'Harley Quinn™ to the rescue',
#        'Lashina™ Tank', 'Batman™ Classic TV Series – Batcave',
#        'Eclipso™ Dark Palace', 'Batman™: Killer Croc™ Sewer Smash',
#        'Batman™: Scarecrow™ Harvest of Fear',
#        'Lena Luthor™ Kryptomite™ Factory', 'Batgirl™ Secret Bunker',
#        'Kryptonite Interception', 'Wonder Woman™ Warrior Battle',
#        "Batman™: Rescue from Ra's al Ghul™", 'Green Lantern vs. Sinestro',
#        'Bumblebee™ Helicopter', 'Clash of the Heroes',
#        'Mighty Micros: Superman™ vs. Bizarro™',
#        'Mighty Micros: Batman™ vs. Killer Moth™',
#        'Mighty Micros: Wonder Woman™ vs. Doomsday™',
#        'Teen Titans Go!™ Fun Pack', 'The Powerpuff Girls™ Fun Pack',
#        'The Powerpuff Girls™ Team Pack', 'Beetlejuice™ Fun Pack',
#        'Teen Titans Go!™ Team Pack', 'Ghostbusters™ Story Pack',
#        'THE LEGO® BATMAN MOVIE Story Pack', 'Goonies™ Level Pack',
#        'Mission: Impossible™ Level Pack', 'DC Comics™ Team Pack',
#        'Midway Arcade™ Level Pack', 'Harry Potter™ Fun Pack',
#        'LEGO® City Fun Pack', 'Cyberman™ Fun Pack',
#        'LEGO® DIMENSIONS™ Gollum Fun Pack',
#        'LEGO® DIMENSIONS™ Eris Fun Pack', 'The Disney Castle',
#        'Silent Mary', "Elsa's Magical Ice Palace",
#        "Cinderella's Dream Castle", "Ariel's Royal Celebration Boat",
#        'Moana’s Ocean Voyage', "Sleeping Beauty's Fairytale Castle",
#        "Cinderella's Enchanted Evening", 'Thunder Hollow Crazy 8 Race',
#        'Ariel and the Magical Spell', "Anna & Elsa's Frozen Playground",
#        "Smokey's Garage", "Willy's Butte Speed Training",
#        "Elsa's Market Adventure", "Mulan's Training Day",
#        'Lightning McQueen Speed Launcher', "Mater's Junkyard",
#        'Castle Interior Kit', 'Mini-Doll Dress-Up Kit',
#        "Guido and Luigi's Pit Stop", 'Cruz Ramirez Race Simulator',
#        'Anna & Kristoff’s Sleigh Adventure', 'Moana’s Island Adventure',
#        'Palace Pets Royal Castle', "Anna's Snow Adventure",
#        "Petite's Royal Stable", "Berry's Kitchen", 'T. rex Tower',
#        'Gentle Giants Petting Zoo', 'Deluxe Train Set',
#        'Around the World', 'Big Fair', 'Farm Adventures', 'Town Square',
#        'Big Construction Site', 'Large Playground Brick Box',
#        'My First Train Set', 'Family House', 'Minnie Mouse Bow-tique',
#        'Fun Family Fair', "Flo's Café", 'Mickey & Friends Beach House',
#        'Pizzeria', 'Batwing Adventure', 'Piston Cup Race',
#        "Santa's Winter Holiday", 'Spider-Man & Hulk Adventures',
#        'My First Animal Brick Box', 'Rapunzel´s Tower',
#        'Farm Pony Stable', 'Fun Creations',
#        'LEGO® DUPLO® All-in-One-Box-of-Fun', 'Fire Truck',
#        'Mickey & Minnie Birthday Parade', 'Shooting Gallery',
#        'My First Carousel', 'Airport', 'Preschool', 'Number Train',
#        'My First Cars and Trucks', 'Truck & Tracked Excavator',
#        'Mater´s Shed', "Farmers' Market", 'Belle´s Tea Party',
#        'My First Emotions', 'Mickey Racer', 'Birthday Picnic',
#        'Police Patrol', 'My First Celebration',
#        'LEGO® DUPLO® Green Baseplate', 'Family Pets', 'Farm Animals',
#        'My First Puzzle Pets', 'My First Bus', 'My First Ladybug',
#        'My First Race Car', 'Spider-Man Spider Truck Adventure',
#        'Spider-Man Web-Bike Workshop',
#        'LEGO® DUPLO® Creative Building Basket', 'Jungle',
#        'Cinderella´s Magical Castle', 'Doc McStuffins™ Backyard Clinic',
#        'Sofia the First Magical Carriage', 'LEGO® DUPLO® Creative Chest',
#        'Doc McStuffins´ Pet Vet Care', 'My First Playhouse',
#        'My First Truck', 'My First Tractor', 'Baby Animals',
#        'Little Plane', 'My First Caterpillar', 'My First Plane',
#        'My First Bird', 'My First Cakes',
#        "Breakout from the Goblin King's Fortress",
#        "Noctura's Tower & the Earth Fox Rescue",
#        "Rosalyn's Healing Hideout", 'Aira & the Song of the Wind Dragon',
#        "The Goblin King's Evil Dragon", 'Azari & the Fire Lion Capture',
#        'Naida & the Water Turtle Ambush',
#        'Azari & the Goblin Forest Escape',
#        'Emily Jones & the Eagle Getaway',
#        'Magic Rescue from the Goblin Village',
#        "Naida's Gondola & the Goblin Thief",
#        'The Capture of Sophie Jones', 'Heartlake Hospital',
#        "Stephanie's House", 'Sunshine Catamaran', 'Friendship House',
#        'Snow Resort Ski Lift', "Mia's Camper Van",
#        'Heartlake Summer Pool', "Stephanie's Sports Arena",
#        'Heartlake Frozen Yogurt Shop', 'Snow Resort Chalet',
#        'Heartlake City Playground', "Emma's Art Café", "Mia's Tree House",
#        'Snow Resort Ice Rink', "Andrea's Speedboat Transporter",
#        'Heartlake Pizzeria', 'Snow Resort Hot Chocolate Van',
#        "Andrea's Park Performance", "Olivia's Mission Vehicle",
#        "Emma's Art Stand", "Mia's Organic Food Market",
#        'Heartlake Surf Shop', "Stephanie's Soccer Practice",
#        "Olivia's Deluxe Bedroom", "Emma's Pet Party",
#        "Stephanie's Bedroom", "Mia's Bedroom",
#        'LEGO® Friends Buildable Hedgehog Storage',
#        'Heartlake Puppy Daycare', 'Heartlake Party Shop',
#        'Amusement Park Space Ride', 'Puppy Playground',
#        'Amusement Park Roller Coaster', 'Heartlake Performance School',
#        'Heartlake Riding Club', 'Heartlake Sports Center',
#        'LEGO® Friends Advent Calendar', 'Puppy Championship',
#        'Heartlake Gift Delivery', 'Puppy Parade', 'Amusement Park Arcade',
#        "Mia's Beach Scooter", "Andrea's Musical Duet",
#        "Foal's Washing Station", 'Puppy Pampering',
#        'Firehouse Headquarters', 'Ecto-1 & 2', 'Ship in a Bottle',
#        'TRON: Legacy', 'Old Fishing Store', 'LEGO® NASA Apollo Saturn V',
#        'Adventure Time™', 'Women of NASA', 'Caterham Seven 620R',
#        'T. rex Breakout', 'The Great Home Escape', 'Raptor Rescue Truck',
#        'Underminer Bank Heist', 'Pteranodon Escape',
#        "Elastigirl's Rooftop Pursuit", 'Florida 500 Final Race',
#        'Demolition Site', "Mia's Farm Suitcase",
#        'Spider-Man vs. Scorpion Street Showdown', 'Shark Attack',
#        'Fire Patrol Suitcase', "Zane's Ninja Boat Pursuit",
#        "Snow White's Forest Cottage", 'Batman™ vs. Mr. Freeze™',
#        "Andrea & Stephanie's Beach Holiday", 'Spider-Man™ Hideout',
#        'Lost Temple', 'Police Truck Chase', 'Snake Showdown',
#        "Stephanie's Horse Carriage", 'Ariel’s Dolphin Carriage',
#        'Police Helicopter Chase', 'Indoraptor Rampage at Lockwood Estate',
#        'Carnotaurus Gyrosphere Escape', 'T. rex Transport',
#        'Jurassic Park Velociraptor Chase', 'Dilophosaurus Outpost Attack',
#        "Blue's Helicopter Pursuit", 'Stygimoloch Breakout',
#        'Pteranodon Chase', 'The Hulkbuster: Ultron Edition',
#        'Sanctum Sanctorum Showdown', 'Thanos: Ultimate Battle',
#        'Corvus Glaive Thresher Attack', 'The Hulkbuster Smash-Up',
#        "Thor's Weapon Quest", 'Outrider Dropship Attack',
#        'Thor vs. Hulk: Arena Clash', 'Hulk vs. Red Hulk',
#        'The Ultimate Battle for Asgard', 'Beware the Vulture',
#        'Royal Talon Fighter Attack', 'Iron Man: Detroit Steel Strikes',
#        'Rhino Face-Off by the Mine', 'ATM Heist Battle',
#        'Captain America Jet Pursuit', 'Mighty Micros: Thor vs. Loki',
#        'Mighty Micros: Star-Lord vs. Nebula',
#        'Mighty Micros: Scarlet Spider vs. Sandman',
#        'Mighty Micros: Spider-Man vs. Scorpion', "Ayesha's Revenge",
#        'Tanker Truck Takedown', "Doctor Strange's Sanctum Sanctorum",
#        'Ravager Attack', 'Iron Man vs. Ultron',
#        'Mighty Micros: Iron Man vs. Thanos',
#        'Mighty Micros: Wolverine vs. Magneto', 'LEGO® MINDSTORMS® EV3',
#        'EV3 Intelligent Brick', 'EV3 Rechargeable DC Battery',
#        'EV3 Color Sensor', 'EV3 Gyro Sensor', 'EV3 Infrared Sensor',
#        'EV3 Infrared Beacon', 'Transformer 10V DC',
#        'EV3 Large Servo Motor', 'EV3 Medium Servo Motor',
#        'EV3 Touch Sensor', 'EV3 Cable Pack', 'EV3 Ultrasonic Sensor',
#        'The Mountain Cave', 'The Ocean Monument', 'The Waterfall Base',
#        'The Crafting Box 2.0', 'The Farm Cottage', 'The Nether Portal',
#        'The Polar Igloo', 'The Nether Railway', 'The Chicken Coop',
#        'The Zombie Cave', 'The Iron Golem', 'The Mushroom Island',
#        'The Nether Fight', 'The Melon Farm', 'The Nether Fortress',
#        'The Jungle Tree House', 'The End Portal', 'The Desert Outpost',
#        'The Wither', 'The Dungeon', 'Series 18: Party',
#        'THE LEGO® BATMAN MOVIE Series 2', 'THE LEGO® NINJAGO® MOVIE™',
#        'Series 17', 'Knighton Castle', "Axl's Rolling Arsenal",
#        "Aaron's X-bow", 'Tech Wizard Showdown', 'Berserker Bomber',
#        'Twinfector', "Lance's Hover Jouster", "Aaron's Stone Destroyer",
#        'Battle Suit Axl', "King's Guard Artillery", 'The Fortrex',
#        "Jestro's Headquarters", "Axl's Tower Carrier",
#        "Aaron's Rock Climber", "Axl's Rumble Maker",
#        "General Magmar's Siege Machine of Doom", 'Lance vs. lightning',
#        'The Three Brothers', "Ruina's Lock & Roller",
#        "Lance's Twin Jouster", 'Moltor’s Lava Smasher',
#        "Macy's Bot Drop Dragon", 'Battle Suit Clay', 'Battle Suit Lance',
#        'Battle Suit Aaron', 'Ultimate Flama', 'Ultimate Lance',
#        'Battle Suit Macy', 'Ultimate Axl', 'Ultimate General Magmar',
#        'LEGO® NEXO KNIGHTS™ Monsters Army-Building Set',
#        'Combo NEXO Powers Wave 1', "Destiny's Bounty", 'NINJAGO® City',
#        'Temple of The Ultimate Ultimate Weapon', 'Quake Mech',
#        'garmadon, Garmadon, GARMADON!', 'Ice Tank',
#        'Temple of Resurrection', 'Fire Mech', 'Garma Mecha Man',
#        'Lightning Jet', 'Killow vs. Samurai X', "Garmadon's Volcano Lair",
#        'Green Ninja Mech Dragon', 'S.O.G. Headquarters',
#        'Ninja Nightcrawler', 'Street Race of Snake Jaguar',
#        'Water Strider', 'Master Falls', 'Manta Ray Bomber',
#        'Flying Jelly Sub', 'Katana V11', 'Piranha Attack',
#        'NINJAGO® City Chase', 'Lloyd - Spinjitzu Master',
#        'Kai - Spinjitzu Master', 'Jay - Spinjitzu Master',
#        'Cole - Spinjitzu Master', 'Spinjitzu Training',
#        'Nya - Spinjitzu Master', 'Zane - Spinjitzu Master',
#        'Misfortune’s Keep', 'Salvage M.E.C.', 'Vermillion Invader',
#        "Destiny's Shadow", 'Raid Zeppelin', 'Sky Shark',
#        'The Vermillion Attack', 'Connections Kit',
#        'Window Exploration Bag', 'Starter Kit',
#        'Identity and Landscape Kit', 'Ferrari Ultimate Garage',
#        'Porsche 911 RSR and 911 Turbo 3.0', '1968 Ford Mustang Fastback',
#        'Ferrari 488 GT3 “Scuderia Corsa”', 'Ford Fiesta M-Sport WRC',
#        'MERCEDES AMG PETRONAS Formula One™ Team',
#        '2016 Ford GT & 1966 Ford GT40', 'Porsche 919 Hybrid',
#        'Mercedes-AMG GT3', 'McLaren 720S', 'Scuderia Ferrari SF16-H',
#        'Bugatti Chiron', 'Ford Mustang GT', 'Audi R18 e-tron quattro',
#        'Kessel Run Millennium Falcon™', 'Imperial TIE Fighter™',
#        "Moloch's Landspeeder™", "Yoda's Hut", "Han Solo's Landspeeder™",
#        'Darth Maul™', 'Range Trooper™',
#        'Jedi™ and Clone Troopers™ Battle Pack',
#        'Imperial Patrol Battle Pack', 'Death Star™', 'Slave I',
#        'First Order Star Destroyer™', 'First Order Heavy Assault Walker™',
#        'Resistance Bomber', 'BB-8™', "Krennic's Imperial Shuttle",
#        'The Arrowhead', 'Defense of Crait™', "Kylo Ren's TIE Fighter™",
#        "Poe's X-Wing Fighter™", 'Rebel U-Wing Fighter™',
#        'Rathtar™ Escape', 'Tracker I', 'Y-Wing Starfighter™',
#        'Scout Trooper™ & Speeder Bike™', 'Jakku Quadjumper™',
#        'First Order Heavy Scout Walker™', 'Mos Eisley Cantina™',
#        'First Order AT-ST™', 'Ahch-To Island™ Training', 'Sandspeeder™',
#        'Desert Skiff Escape', "General Grievous' Combat Speeder",
#        'Resistance Transport Pod™', 'Darth Vader™ Transformation',
#        "Yoda's Jedi Starfighter™", 'Republic Fighter Tank™',
#        'Duel on Naboo™', 'Elite Praetorian Guard',
#        'Stormtrooper™ Commander',
#        'A-Wing™ vs. TIE Silencer™ Microfighters',
#        'Ski Speeder™ vs. First Order Walker™ Microfighters',
#        'Elite TIE Fighter Pilot™', 'Tatooine™ Battle Pack',
#        'First Order Specialists Battle Pack',
#        'Bounty Hunter Speeder Bike™ Battle Pack',
#        'First Order Transport Speeder Battle Pack',
#        'Millennium Falcon™ Microfighter',
#        'First Order TIE Fighter™ Microfighter', 'U-Wing™ Microfighter',
#        'TIE Striker™ Microfighter', 'Snowspeeder™',
#        'Jedi Starfighter™ With Hyperdrive', 'Darth Vader™', 'Boba Fett™',
#        "Luke's Landspeeder™", 'Millennium Falcon™', 'Sergeant Jyn Erso™',
#        'Chirrut Îmwe™', 'Baze Malbus™', 'Imperial Trooper Battle Pack',
#        'TIE Fighter™', 'Kylo Ren’s Command Shuttle™', 'TIE Striker™',
#        'Battle on Takodana™', 'Battle on Scarif', 'StarScavenger™',
#        'Encounter on Jakku™', 'LEGO® Star Wars™ Advent Calendar',
#        'The Phantom', 'K-2SO™', 'Obi-Wan Kenobi™',
#        'Imperial Death Trooper™', "Rey's Speeder™",
#        'Scarif Stormtrooper™', 'Jango Fett™', 'First Order Stormtrooper™',
#        'Rebel Trooper Battle Pack', 'Resistance Trooper Battle Pack',
#        'First Order Battle Pack', 'Y-Wing™ Microfighter',
#        'Resistance X-Wing Fighter™', 'TIE Advanced Prototype™',
#        "Krennic's Imperial Shuttle™ Microfighter",
#        'First Order Snowspeeder™', '6x6 All Terrain Tow Truck',
#        'Porsche 911 GT3 RS', 'Bucket Wheel Excavator', 'Mack Anthem',
#        'Extreme Adventure', 'Air Race Jet', 'Ocean Explorer', 'Rally Car',
#        'RC Tracked Racer', 'Airport Rescue Vehicle', 'Hovercraft',
#        'BMW R 1200 GS Adventure', 'Container Yard', 'First Responder',
#        'Racing Yacht', 'Roadwork Crew', 'LEGO® Power Functions Motor Set',
#        'WHACK!', 'BASH!', 'Ultralight Helicopter', 'Stunt Bike',
#        'Dozer Compactor', 'Hook Loader', 'CLAAS XERION 5000 TRAC VC',
#        'Heavy Lift Helicopter', '24 Hours Race Car', 'Volvo EW160E',
#        'Formula Off-Roader', 'Mine Loader', 'Street Motorcycle',
#        'Telehandler', 'Compact Tracked Loader', 'Record Breaker',
#        'Hydroplane Racer', 'Cherry Picker', 'Display Team Jet',
#        'Arkham Asylum', 'The Ultimate Batmobile', 'Batcave Break-in',
#        'The Batwing', 'The Batmobile', 'The Joker™ Notorious Lowrider',
#        'Bane™ Toxic Truck Attack', 'The Penguin™ Arctic Roller',
#        'The Riddler™ Riddle Racer', 'Scarecrow™ Special Delivery',
#        'Mr. Freeze™ Ice Attack', 'Scarecrow™ Fearful Face-off',
#        'The Joker™ Balloon Escape',
#        'THE LEGO® BATMAN MOVIE Batman™ Minifigure Collector Frame',
#        'The Scuttler', 'Killer Croc™ Tail-Gator',
#        'Two-Face™ Double Demolition', 'Clayface™ Splat Attack',
#        'Catwoman™ Catcycle Chase', 'Creative Box', 'Creative Builder Box',
#        'Bricks on a Roll', 'Vacation Getaways', 'Winter Toy Shop',
#        'The Ghostbusters™ Level Pack', 'Adventure Time™ Level Pack',
#        'Harry Potter™ Team Pack', 'Adventure Time™ Team Pack',
#        'Excalibur Batman™ Fun Pack', 'A-Team™ Fun Pack',
#        'Sensei Wu Fun Pack', 'Bane™ Fun Pack', 'Knight Rider™ Fun Pack',
#        'LEGO® DUPLO® Creative Box', 'My First Bricks',
#        'Green LEGO® DUPLO® Baseplate', 'Touch Sensor',
#        'Temple of Airjitzu', 'A-Wing Starfighter™',
#        'Power Functions Motor Set', 'Starter Pack PLAYSTATION® 4',
#        'Zane Fun Pack', 'Portal® 2 Level Pack', 'Wicked Witch™ Fun Pack',
#        "Vaiana's Ocean Voyage", 'Slave I™', "Moana's Ocean Voyage",
#        'My First Vehicles'], dtype=object)

# %%
#Keep tinkering!
df.play_star_rating.value_counts?

# %% [markdown]
# # Practice questions
#
# It's time to put a little bit of this into practice.

# %% [markdown]
# ## 1. What are the 5 most common theme names?

# %%
#Your code/answer here
df.theme_name.value_counts()[:5]
#Star Wars, DIPLO, City, Juniors, THE LEGO NINJAGO MOVIE
# Out:
# Star Wars™                   1377
# DUPLO®                       1166
# City                         1092
# Juniors                       978
# THE LEGO® NINJAGO® MOVIE™     796
# Name: theme_name, dtype: int64

# %% [markdown]
# ## 2. What was the average lego set price?

# %%
#Your code/answer here
df.list_price.mean()
#65.14199840958968
# Out:
# 65.14199840958968

# %% [markdown]
# ## 3. Which set do you think is the most popular?

# %%
#Your code/answer here

df.sort_values(['num_reviews', 'star_rating', 'play_star_rating', 'val_star_rating'], ascending = False)[:60]
#LEGO NASA Apollo Saturn V
# Out:
#       ages  list_price  num_reviews  piece_count  play_star_rating  \
# 409    14+    119.9900        367.0       1969.0               4.6
# 1099   14+    129.1924        367.0       1969.0               4.6
# 1674   14+    146.3878        367.0       1969.0               4.6
# 2240   14+    158.5878        367.0       1969.0               4.6
# 2937   14+    116.9922        367.0       1969.0               4.6
# 3629   14+    141.7800        367.0       1969.0               4.6
# 4174   14+    158.3520        367.0       1969.0               4.6
# 4723   14+    158.5878        367.0       1969.0               4.6
# 5295   14+    131.8800        367.0       1969.0               4.6
# 5847   14+    158.5878        367.0       1969.0               4.6
# 6396   14+    170.7390        367.0       1969.0               4.6
# 6961   14+    146.3878        367.0       1969.0               4.6
# 7537   14+    153.9860        367.0       1969.0               4.6
# 8108   14+    146.3878        367.0       1969.0               4.6
# 8658   14+    146.3878        367.0       1969.0               4.6
# 9208   14+    158.5878        367.0       1969.0               4.6
# 9757   14+    181.8700        367.0       1969.0               4.6
# 10330  14+    158.5878        367.0       1969.0               4.6
# 10901  14+    141.9929        367.0       1969.0               4.6
# 11435  14+    153.6971        367.0       1969.0               4.6
# 11976  14+    158.5878        367.0       1969.0               4.6
# 177    16+    119.9900        337.0       1334.0               4.3
# 944    16+    129.1924        337.0       1334.0               4.3
# 1514   16+    121.9878        337.0       1334.0               4.3
# 2090   16+    121.9878        337.0       1334.0               4.3
# 2705   16+    101.3922        337.0       1334.0               4.3
# 3470   16+    121.3800        337.0       1334.0               4.3
# 4038   16+    143.9520        337.0       1334.0               4.3
# 4587   16+    121.9878        337.0       1334.0               4.3
# 5135   16+     95.8800        337.0       1334.0               4.3
# 5711   16+    121.9878        337.0       1334.0               4.3
# 6260   16+    134.1390        337.0       1334.0               4.3
# 6809   16+    121.9878        337.0       1334.0               4.3
# 7377   16+    118.9860        337.0       1334.0               4.3
# 7950   16+    121.9878        337.0       1334.0               4.3
# 8522   16+    121.9878        337.0       1334.0               4.3
# 9073   16+    121.9878        337.0       1334.0               4.3
# 9621   16+    142.8700        337.0       1334.0               4.3
# 10171  16+    121.9878        337.0       1334.0               4.3
# 10746  16+    141.9929        337.0       1334.0               4.3
# 11311  16+    130.4971        337.0       1334.0               4.3
# 11840  16+    121.9878        337.0       1334.0               4.3
# 170    16+    239.9900        228.0       4295.0               4.2
# 936    16+    288.7924        228.0       4295.0               4.2
# 1506   16+    268.3878        228.0       4295.0               4.2
# 2082   16+    268.3878        228.0       4295.0               4.2
# 2697   16+    233.9922        228.0       4295.0               4.2
# 3462   16+    264.1800        228.0       4295.0               4.2
# 4030   16+    311.9520        228.0       4295.0               4.2
# 4579   16+    280.5878        228.0       4295.0               4.2
# 5127   16+    251.8800        228.0       4295.0               4.2
# 5703   16+    280.5878        228.0       4295.0               4.2
# 6252   16+    329.3390        228.0       4295.0               4.2
# 6802   16+    268.3878        228.0       4295.0               4.2
# 7368   16+    307.9860        228.0       4295.0               4.2
# 7941   16+    309.8678        228.0       4295.0               4.2
# 8515   16+    268.3878        228.0       4295.0               4.2
# 9065   16+    268.3878        228.0       4295.0               4.2
# 9612   16+    389.8700        228.0       4295.0               4.2
# 10163  16+    268.3878        228.0       4295.0               4.2
#
#                                                prod_desc  prod_id  \
# 409    Build the first rocket to land people on the M...  21309.0
# 1099   Build the first rocket to land people on the M...  21309.0
# 1674   Build the first rocket to land people on the M...  21309.0
# 2240   Build the first rocket to land people on the M...  21309.0
# 2937   Build the first rocket to land people on the M...  21309.0
# 3629   Build the first rocket to land people on the M...  21309.0
# 4174   Build the first rocket to land people on the M...  21309.0
# 4723   Build the first rocket to land people on the M...  21309.0
# 5295   Build the first rocket to land people on the M...  21309.0
# 5847   Build the first rocket to land people on the M...  21309.0
# 6396   Build the first rocket to land people on the M...  21309.0
# 6961   Build the first rocket to land people on the M...  21309.0
# 7537   Build the first rocket to land people on the M...  21309.0
# 8108   Build the first rocket to land people on the M...  21309.0
# 8658   Build the first rocket to land people on the M...  21309.0
# 9208   Build the first rocket to land people on the M...  21309.0
# 9757   Build the first rocket to land people on the M...  21309.0
# 10330  Build the first rocket to land people on the M...  21309.0
# 10901  Build the first rocket to land people on the M...  21309.0
# 11435  Build the first rocket to land people on the M...  21309.0
# 11976  Build the first rocket to land people on the M...  21309.0
# 177    Road trips will never be the same again with t...  10220.0
# 944    Road trips will never be the same again with t...  10220.0
# 1514   Road trips will never be the same again with t...  10220.0
# 2090   Road trips will never be the same again with t...  10220.0
# 2705   Road trips will never be the same again with t...  10220.0
# 3470   Road trips will never be the same again with t...  10220.0
# 4038   Road trips will never be the same again with t...  10220.0
# 4587   Road trips will never be the same again with t...  10220.0
# 5135   Road trips will never be the same again with t...  10220.0
# 5711   Road trips will never be the same again with t...  10220.0
# 6260   Road trips will never be the same again with t...  10220.0
# 6809   Road trips will never be the same again with t...  10220.0
# 7377   Road trips will never be the same again with t...  10220.0
# 7950   Road trips will never be the same again with t...  10220.0
# 8522   Road trips will never be the same again with t...  10220.0
# 9073   Road trips will never be the same again with t...  10220.0
# 9621   Road trips will never be the same again with t...  10220.0
# 10171  Road trips will never be the same again with t...  10220.0
# 10746  Road trips will never be the same again with t...  10220.0
# 11311  Road trips will never be the same again with t...  10220.0
# 11840  Road trips will never be the same again with t...  10220.0
# 170                  Build London's famous Tower Bridge!  10214.0
# 936                  Build London's famous Tower Bridge!  10214.0
# 1506                 Build London's famous Tower Bridge!  10214.0
# 2082                 Build London's famous Tower Bridge!  10214.0
# 2697                 Build London's famous Tower Bridge!  10214.0
# 3462                 Build London's famous Tower Bridge!  10214.0
# 4030                 Build London's famous Tower Bridge!  10214.0
# 4579                 Build London's famous Tower Bridge!  10214.0
# 5127                 Build London's famous Tower Bridge!  10214.0
# 5703                 Build London's famous Tower Bridge!  10214.0
# 6252                 Build London's famous Tower Bridge!  10214.0
# 6802                 Build London's famous Tower Bridge!  10214.0
# 7368                 Build London's famous Tower Bridge!  10214.0
# 7941                 Build London's famous Tower Bridge!  10214.0
# 8515                 Build London's famous Tower Bridge!  10214.0
# 9065                 Build London's famous Tower Bridge!  10214.0
# 9612                 Build London's famous Tower Bridge!  10214.0
# 10163                Build London's famous Tower Bridge!  10214.0
#
#                                           prod_long_desc review_difficulty  \
# 409    Display and role-play with this majestic meter...       Challenging
# 1099   Display and role-play with this majestic meter...       Challenging
# 1674   Display and role-play with this majestic meter...       Challenging
# 2240   Display and role-play with this majestic meter...       Challenging
# 2937   Display and role-play with this majestic meter...       Challenging
# 3629   Display and role-play with this majestic meter...       Challenging
# 4174   Display and role-play with this majestic meter...       Challenging
# 4723   Display and role-play with this majestic meter...       Challenging
# 5295   Display and role-play with this majestic meter...       Challenging
# 5847   Display and role-play with this majestic meter...       Challenging
# 6396   Display and role-play with this majestic meter...       Challenging
# 6961   Display and role-play with this majestic meter...       Challenging
# 7537   Display and role-play with this majestic meter...       Challenging
# 8108   Display and role-play with this majestic meter...       Challenging
# 8658   Display and role-play with this majestic meter...       Challenging
# 9208   Display and role-play with this majestic meter...       Challenging
# 9757   Display and role-play with this majestic meter...       Challenging
# 10330  Display and role-play with this majestic meter...       Challenging
# 10901  Display and role-play with this majestic meter...       Challenging
# 11435  Display and role-play with this majestic meter...       Challenging
# 11976  Display and role-play with this majestic meter...       Challenging
# 177    This authentic camper van is a replica of the ...       Challenging
# 944    This authentic camper van is a replica of the ...       Challenging
# 1514   This authentic camper van is a replica of the ...       Challenging
# 2090   This authentic camper van is a replica of the ...       Challenging
# 2705   This authentic camper van is a replica of the ...       Challenging
# 3470   This authentic camper van is a replica of the ...       Challenging
# 4038   This authentic camper van is a replica of the ...       Challenging
# 4587   This authentic camper van is a replica of the ...       Challenging
# 5135   This authentic camper van is a replica of the ...       Challenging
# 5711   This authentic camper van is a replica of the ...       Challenging
# 6260   This authentic camper van is a replica of the ...       Challenging
# 6809   This authentic camper van is a replica of the ...       Challenging
# 7377   This authentic camper van is a replica of the ...       Challenging
# 7950   This authentic camper van is a replica of the ...       Challenging
# 8522   This authentic camper van is a replica of the ...       Challenging
# 9073   This authentic camper van is a replica of the ...       Challenging
# 9621   This authentic camper van is a replica of the ...       Challenging
# 10171  This authentic camper van is a replica of the ...       Challenging
# 10746  This authentic camper van is a replica of the ...       Challenging
# 11311  This authentic camper van is a replica of the ...       Challenging
# 11840  This authentic camper van is a replica of the ...       Challenging
# 170    Stretching over the River Thames since 1894, t...       Challenging
# 936    Stretching over the River Thames since 1894, t...       Challenging
# 1506   Stretching over the River Thames since 1894, t...       Challenging
# 2082   Stretching over the River Thames since 1894, t...       Challenging
# 2697   Stretching over the River Thames since 1894, t...       Challenging
# 3462   Stretching over the River Thames since 1894, t...       Challenging
# 4030   Stretching over the River Thames since 1894, t...       Challenging
# 4579   Stretching over the River Thames since 1894, t...       Challenging
# 5127   Stretching over the River Thames since 1894, t...       Challenging
# 5703   Stretching over the River Thames since 1894, t...       Challenging
# 6252   Stretching over the River Thames since 1894, t...       Challenging
# 6802   Stretching over the River Thames since 1894, t...       Challenging
# 7368   Stretching over the River Thames since 1894, t...       Challenging
# 7941   Stretching over the River Thames since 1894, t...       Challenging
# 8515   Stretching over the River Thames since 1894, t...       Challenging
# 9065   Stretching over the River Thames since 1894, t...       Challenging
# 9612   Stretching over the River Thames since 1894, t...       Challenging
# 10163  Stretching over the River Thames since 1894, t...       Challenging
#
#                          set_name  star_rating      theme_name  \
# 409    LEGO® NASA Apollo Saturn V          4.9           Ideas
# 1099   LEGO® NASA Apollo Saturn V          4.9           Ideas
# 1674   LEGO® NASA Apollo Saturn V          4.9           Ideas
# 2240   LEGO® NASA Apollo Saturn V          4.9           Ideas
# 2937   LEGO® NASA Apollo Saturn V          4.9           Ideas
# 3629   LEGO® NASA Apollo Saturn V          4.9           Ideas
# 4174   LEGO® NASA Apollo Saturn V          4.9           Ideas
# 4723   LEGO® NASA Apollo Saturn V          4.9           Ideas
# 5295   LEGO® NASA Apollo Saturn V          4.9           Ideas
# 5847   LEGO® NASA Apollo Saturn V          4.9           Ideas
# 6396   LEGO® NASA Apollo Saturn V          4.9           Ideas
# 6961   LEGO® NASA Apollo Saturn V          4.9           Ideas
# 7537   LEGO® NASA Apollo Saturn V          4.9           Ideas
# 8108   LEGO® NASA Apollo Saturn V          4.9           Ideas
# 8658   LEGO® NASA Apollo Saturn V          4.9           Ideas
# 9208   LEGO® NASA Apollo Saturn V          4.9           Ideas
# 9757   LEGO® NASA Apollo Saturn V          4.9           Ideas
# 10330  LEGO® NASA Apollo Saturn V          4.9           Ideas
# 10901  LEGO® NASA Apollo Saturn V          4.9           Ideas
# 11435  LEGO® NASA Apollo Saturn V          4.9           Ideas
# 11976  LEGO® NASA Apollo Saturn V          4.9           Ideas
# 177      Volkswagen T1 Camper Van          4.7  Creator Expert
# 944      Volkswagen T1 Camper Van          4.7  Creator Expert
# 1514     Volkswagen T1 Camper Van          4.7  Creator Expert
# 2090     Volkswagen T1 Camper Van          4.7  Creator Expert
# 2705     Volkswagen T1 Camper Van          4.7  Creator Expert
# 3470     Volkswagen T1 Camper Van          4.7  Creator Expert
# 4038     Volkswagen T1 Camper Van          4.7  Creator Expert
# 4587     Volkswagen T1 Camper Van          4.7  Creator Expert
# 5135     Volkswagen T1 Camper Van          4.7  Creator Expert
# 5711     Volkswagen T1 Camper Van          4.7  Creator Expert
# 6260     Volkswagen T1 Camper Van          4.7  Creator Expert
# 6809     Volkswagen T1 Camper Van          4.7  Creator Expert
# 7377     Volkswagen T1 Camper Van          4.7  Creator Expert
# 7950     Volkswagen T1 Camper Van          4.7  Creator Expert
# 8522     Volkswagen T1 Camper Van          4.7  Creator Expert
# 9073     Volkswagen T1 Camper Van          4.7  Creator Expert
# 9621     Volkswagen T1 Camper Van          4.7  Creator Expert
# 10171    Volkswagen T1 Camper Van          4.7  Creator Expert
# 10746    Volkswagen T1 Camper Van          4.7  Creator Expert
# 11311    Volkswagen T1 Camper Van          4.7  Creator Expert
# 11840    Volkswagen T1 Camper Van          4.7  Creator Expert
# 170                  Tower Bridge          4.8  Creator Expert
# 936                  Tower Bridge          4.8  Creator Expert
# 1506                 Tower Bridge          4.8  Creator Expert
# 2082                 Tower Bridge          4.8  Creator Expert
# 2697                 Tower Bridge          4.8  Creator Expert
# 3462                 Tower Bridge          4.8  Creator Expert
# 4030                 Tower Bridge          4.8  Creator Expert
# 4579                 Tower Bridge          4.8  Creator Expert
# 5127                 Tower Bridge          4.8  Creator Expert
# 5703                 Tower Bridge          4.8  Creator Expert
# 6252                 Tower Bridge          4.8  Creator Expert
# 6802                 Tower Bridge          4.8  Creator Expert
# 7368                 Tower Bridge          4.8  Creator Expert
# 7941                 Tower Bridge          4.8  Creator Expert
# 8515                 Tower Bridge          4.8  Creator Expert
# 9065                 Tower Bridge          4.8  Creator Expert
# 9612                 Tower Bridge          4.8  Creator Expert
# 10163                Tower Bridge          4.8  Creator Expert
#
#        val_star_rating country
# 409                4.9      US
# 1099               4.9      AU
# 1674               4.9      AT
# 2240               4.9      BE
# 2937               4.9      CA
# 3629               4.9      CH
# 4174               4.9      CZ
# 4723               4.9      DE
# 5295               4.9      DN
# 5847               4.9      ES
# 6396               4.9      FI
# 6961               4.9      FR
# 7537               4.9      GB
# 8108               4.9      IE
# 8658               4.9      IT
# 9208               4.9      LU
# 9757               4.9      NO
# 10330              4.9      NL
# 10901              4.9      NZ
# 11435              4.9      PL
# 11976              4.9      PT
# 177                4.5      US
# 944                4.5      AU
# 1514               4.5      AT
# 2090               4.5      BE
# 2705               4.5      CA
# 3470               4.5      CH
# 4038               4.5      CZ
# 4587               4.5      DE
# 5135               4.5      DN
# 5711               4.5      ES
# 6260               4.5      FI
# 6809               4.5      FR
# 7377               4.5      GB
# 7950               4.5      IE
# 8522               4.5      IT
# 9073               4.5      LU
# 9621               4.5      NO
# 10171              4.5      NL
# 10746              4.5      NZ
# 11311              4.5      PL
# 11840              4.5      PT
# 170                4.6      US
# 936                4.6      AU
# 1506               4.6      AT
# 2082               4.6      BE
# 2697               4.6      CA
# 3462               4.6      CH
# 4030               4.6      CZ
# 4579               4.6      DE
# 5127               4.6      DN
# 5703               4.6      ES
# 6252               4.6      FI
# 6802               4.6      FR
# 7368               4.6      GB
# 7941               4.6      IE
# 8515               4.6      IT
# 9065               4.6      LU
# 9612               4.6      NO
# 10163              4.6      NL

# %% [markdown]
# # Graphing
#
# Our bread and butter tool for graphing in python will be **matplotlib**.
# There are a number of other packages you can also check out for visualization later on such as plotly, folium, and bokeh to name a few, but matplotlib is an industry standard used widely. As with the pandas package, we must import  the matplotlib package to use its built in functions and methods. Rather then import the entire package however, we import only the piece we intend to use (hence the dot notation) and again alias this under the shorthand *plt*. Finally, the iPython magic command **% matplotlib inline** makes these graphs appear within our jupyter notebook.

# %%
#import a subset of the matplotlib package under the alias 'plt'
import matplotlib.pyplot as plt

#ipython magic command for displaying graphs within the notebook
# %matplotlib inline

# %%
to_graph = df.theme_name.value_counts()[:5]
to_graph.plot(kind='barh')

# %% [markdown]
# # Adding labels
# The graph above is a good start, but we should be sure to add some labels! To do this we make successive calls to the `plt` package we imported. Some common methods you should be familiar with include:
# * plt.title()
# * plt.xlabel()
# * plt.ylabel()
# * plt.legend()
# * plt.xticks()
# * plt.yticks()

# %%
to_graph = df.theme_name.value_counts()[:5]
to_graph.plot(kind='barh') #lots of other optional parameters can be passed such as color
plt.title('Top 5 Lego Themes', fontsize=16) #fontsize is optional
plt.xlabel('Number of Lego Sets') #you could also pass in fontsize if you wanted here
plt.ylabel('Theme', rotation = 360) #you could also rotate text if you wanted
# Out:
# Text(0,0.5,'Theme')

# %% [markdown]
# # Practice and Explore
#
# Take a minute to try chaining some of these methods together to create a few of your own visuals for practice. Some ideas can include making a scatter plot with `plt.scatter(x , y)` where you pass in two series (one as x and the other as y), plotting histograms with the `series.hist()` method, or creating simple bar graphs as shown above.

# %%
plt.scatter(df.play_star_rating, df.star_rating, color = 'red')
plt.xlabel('Star Rating')
plt.ylabel('Play Star Rating')
# Out:
# Text(0,0.5,'Play Star Rating')

# %%
plt.scatter(df.piece_count, df.list_price, color = ['red', 'blue'])
plt.xlabel('Number of Pieces', fontsize = 14)
plt.ylabel('Price', fontsize = 14)
# Out:
# Text(0,0.5,'Price')

# %%
df.play_star_rating.hist(color = '#7F00FF' )
plt.title("Play Star Rating")
plt.yticks(rotation = 45)
# Out:
# (array([   0., 1000., 2000., 3000., 4000., 5000.]),
#  <a list of 6 Text yticklabel objects>)

# %%
dif = df.review_difficulty.value_counts()
dif.plot(kind='bar')
plt.xticks(rotation = 45)
plt.title('Difficulty Levels', fontsize = 18)
# Out:
# Text(0.5,1,'Difficulty Levels')
